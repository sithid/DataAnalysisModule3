# %% [markdown]
# # Workflow Practice
#
# In this notebook, you’ll practice connecting to a SQLite database, creating tables from CSV files using Pandas, and writing SQL queries to explore the data.
#
# The dataset comes from the [Bike Store Sample Database](https://www.kaggle.com/datasets/dillonmyrick/bike-store-sample-database) by Dillon Myrick. It models a fictional bike retailer with multiple stores, products, customers, and staff. Each table connects to others using foreign keys such as `customer_id`, `store_id`, and `product_id`.
#
# You’ll:
# - Connect to a local SQLite database
# - Create tables using `pandas.to_sql()`
# - Write and test SQL queries using `pd.read_sql()`
#
# All of your work will take place directly in this notebook. Each question prompt is written below as a Markdown cell, followed by an empty code cell for you to write your query.

# %% [markdown]
# ## Step 1: Connect to the Database
#
# Run the following cell to connect to (or create) a SQLite database called `bike_store.db`.
# If the file doesn’t exist yet, SQLite will automatically create it.

# %%
import sqlite3
import glob
import pandas as pd

# %%
connection = sqlite3.connect("bike_store.db")
connection

# %% [markdown]
# ## Step 2: Create Tables from CSV Files
#
# The `data/` folder contains one CSV file per table.
# Use `pandas.read_csv()` and `DataFrame.to_sql()` to load each file into your database.
#
# You only need to do this once.
# After that, you’ll be able to run queries against your newly created tables.

# %%
# Example for one file
customers = pd.read_csv("data/customers.csv")
customers.to_sql("customers", connection, if_exists="replace", index=False)
# Out:
# 1445

# %%
# Repeat for all other files in the data folder, or use a loop.
tables = ['data/brands.csv', 'data/categories.csv', 'data/order_items.csv', 'data/orders.csv', 'data/products.csv', 'data/staffs.csv', 'data/stocks.csv', 'data/stores.csv']

path = r"data/*.csv" 

csv_files = glob.glob(path)

for file_path in csv_files:
    print(f"Processing file: {file_path}")
    df = pd.read_csv(file_path)
    
    table_name = file_path.replace('.csv', '').split('\\')[1]

    df.to_sql(table_name, connection, if_exists='replace', index=False)

    print( f"Data from {file_path} has been inserted into biker_store.db as table {table_name}.")
# Out:
# Processing file: data\brands.csv
# Data from data\brands.csv has been inserted into biker_store.db as table brands.
# Processing file: data\categories.csv
# Data from data\categories.csv has been inserted into biker_store.db as table categories.
# Processing file: data\customers.csv
# Data from data\customers.csv has been inserted into biker_store.db as table customers.
# Processing file: data\orders.csv
# Data from data\orders.csv has been inserted into biker_store.db as table orders.
# Processing file: data\order_items.csv
# Data from data\order_items.csv has been inserted into biker_store.db as table order_items.
# Processing file: data\products.csv
# Data from data\products.csv has been inserted into biker_store.db as table products.
# Processing file: data\staffs.csv
# Data from data\staffs.csv has been inserted into biker_store.db as table staffs.
# Processing file: data\stocks.csv
# Data from data\stocks.csv has been inserted into biker_store.db as table stocks.
# Processing file: data\stores.csv
# Data from data\stores.csv has been inserted into biker_store.db as table stores.

# %% [markdown]
# ### Verify Your Tables
#
# Run a query to make sure your tables were created successfully.

# %%
pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", connection)
# Out:
#           name
# 0       brands
# 1   categories
# 2    customers
# 3       orders
# 4  order_items
# 5     products
# 6       staffs
# 7       stocks
# 8       stores

# %% [markdown]
# ## Step 3: Test a Simple Query
#
# Before starting the exercises, confirm your connection and tables are working by previewing the first few rows of the `customers` table.

# %%
pd.read_sql("SELECT discount from order_items", connection)
# Out:
#       discount
# 0         0.20
# 1         0.07
# 2         0.05
# 3         0.05
# 4         0.20
# ...        ...
# 4717      0.07
# 4718      0.20
# 4719      0.20
# 4720      0.07
# 4721      0.20
#
# [4722 rows x 1 columns]

# %% [markdown]
# ### Q1. List all customers and their cities.
#
# Return the first name, last name, and city of each customer. Sort alphabetically by last name and then by first name.

# %%
query1 = """
SELECT
  last_name,
  first_name,
  city
FROM customers
ORDER BY last_name ASC, first_name ASC;
"""

pd.read_sql(query1, connection)
# Out:
#       last_name  first_name                 city
# 0       Acevedo       Ester          San Lorenzo
# 1       Acevedo      Jamika           Ozone Park
# 2       Acevedo       Penny         Ballston Spa
# 3        Acosta    Bettyann            Lancaster
# 4        Acosta       Shery     Saratoga Springs
# ...         ...         ...                  ...
# 1440      Young        Edda      North Tonawanda
# 1441      Young      Jasmin              Helotes
# 1442     Zamora  Alexandria          Schenectady
# 1443     Zamora       Jayme  Springfield Gardens
# 1444  Zimmerman       Ollie              Anaheim
#
# [1445 rows x 3 columns]

# %% [markdown]
# ### Q2. Show all products and their prices.
#
# Display each product name along with its list price. Sort by price in descending order.

# %%
query2 = """
SELECT
  product_name,
  list_price
FROM products
ORDER BY list_price DESC;
"""

pd.read_sql(query2, connection)
# Out:
#                                product_name  list_price
# 0             Trek Domane SLR 9 Disc - 2018    11999.99
# 1             Trek Domane SLR 8 Disc - 2018     7499.99
# 2          Trek Silque SLR 8 Women's - 2017     6499.99
# 3            Trek Domane SL Frameset - 2018     6499.99
# 4    Trek Domane SL Frameset Women's - 2018     6499.99
# ..                                      ...         ...
# 316                    Trek Kickster - 2018      159.99
# 317         Trek Boy's Kickster - 2015/2017      149.99
# 318             Trek Girl's Kickster - 2017      149.99
# 319          Sun Bicycles Lil Kitt'n - 2017      109.99
# 320  Strider Classic 12 Balance Bike - 2018       89.99
#
# [321 rows x 2 columns]

# %% [markdown]
# ### Q3. Find all customers from California.
#
# Return first name, last name, city, and state for all customers whose state is 'CA'. Sort alphabetically by last name.

# %%
query3 = """
SELECT
  last_name,
  first_name,
  city,
  state
FROM customers
WHERE state = 'CA'
ORDER BY last_name ASC;
"""

pd.read_sql(query3, connection)
# Out:
#      last_name first_name                    city state
# 0      Acevedo      Ester             San Lorenzo    CA
# 1       Albert     Jamaal                Torrance    CA
# 2     Anderson      Sindy                  Pomona    CA
# 3       Arnold      Twana                 Anaheim    CA
# 4       Austin     Selene                  Duarte    CA
# ..         ...        ...                     ...   ...
# 279       Witt     Darren               Coachella    CA
# 280      Woods       Lucy  Palos Verdes Peninsula    CA
# 281       Wynn       Joel               San Diego    CA
# 282      Yates      Yvone               San Pablo    CA
# 283  Zimmerman      Ollie                 Anaheim    CA
#
# [284 rows x 4 columns]

# %% [markdown]
# ### Q4. Count how many products are in each category.
#
# Return the category name and the number of products in that category. Sort from the highest count to the lowest.

# %%
query4 = """
SELECT
  c.category_name,
  COUNT(p.product_id) AS product_count
FROM categories c
JOIN products p ON c.category_id = p.category_id
GROUP BY c.category_name
ORDER BY product_count DESC;
"""

pd.read_sql(query4, connection)
# Out:
#          category_name  product_count
# 0    Cruisers Bicycles             78
# 1           Road Bikes             60
# 2       Mountain Bikes             60
# 3    Children Bicycles             59
# 4     Comfort Bicycles             30
# 5       Electric Bikes             24
# 6  Cyclocross Bicycles             10

# %% [markdown]
# ### Q5. Find all orders placed in 2018.
#
# List the order ID, order date, and customer ID for orders made during the year 2018. Sort by order date.

# %%
query5 = """
SELECT
  order_id,
  order_date,
  customer_id
FROM orders
WHERE strftime('%Y', order_date) = '2018'
ORDER BY order_date ASC;
"""

pd.read_sql(query5, connection)
# Out:
#      order_id  order_date  customer_id
# 0        1324  2018-01-01          862
# 1        1325  2018-01-01           68
# 2        1326  2018-01-01          567
# 3        1327  2018-01-02         1026
# 4        1328  2018-01-02         1083
# ..        ...         ...          ...
# 287      1611  2018-09-06            6
# 288      1612  2018-10-21            3
# 289      1613  2018-11-18            1
# 290      1614  2018-11-28          135
# 291      1615  2018-12-28          136
#
# [292 rows x 3 columns]

# %% [markdown]
# ### Q6. Show each order with its total number of items.
#
# Join the `orders` and `order_items` tables. Group by order ID and return the number of items per order.

# %%
query6 = """
SELECT
  o.order_id,
  SUM(oi.quantity) AS total_quantity
FROM orders o 
JOIN order_items oi ON o.order_id = oi.order_id
GROUP BY o.order_id
ORDER BY total_quantity DESC;
"""

pd.read_sql(query6, connection)
# Out:
#       order_id  total_quantity
# 0         1577              10
# 1          944              10
# 2          813              10
# 3          518              10
# 4          100              10
# ...        ...             ...
# 1610        52               1
# 1611        46               1
# 1612        42               1
# 1613        14               1
# 1614        10               1
#
# [1615 rows x 2 columns]

# %% [markdown]
# ### Q7. List total revenue per store.
#
# Revenue = quantity * list_price * (1 - discount). Join `orders`, `order_items`, and `stores`, group by store name, and return total revenue.

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# Your query here
query7 = """
select sum(order_items.quantity * order_items.list_price * (1- order_items.discount)) as total_revenue, stores.store_name
from order_items 
join orders on order_items.order_id = orders.order_id
join stores on orders.store_id = stores.store_id
group by stores.store_name
 """
pd.read_sql(query7, connection)
# Out:
#    total_revenue        store_name
# 0     5215751.28     Baldwin Bikes
# 1      867542.24     Rowlett Bikes
# 2     1605823.04  Santa Cruz Bikes

# %% [markdown]
# ### Q8. Find the top 5 customers who spent the most overall.
#
# Join `customers`, `orders`, and `order_items`. Sum the total spending per customer and return the top five spenders.

# %%
query8 = """
SELECT
  CONCAT(customers.first_name, ' ', customers.last_name) AS customer_name,
  sum(order_items.quantity * order_items.list_price * (1- order_items.discount)) as total_revenue
FROM orders
JOIN customers ON orders.customer_id = customers.customer_id
JOIN order_items ON orders.order_id = order_items.order_id
GROUP BY customers.customer_id
ORDER BY total_revenue DESC LIMIT 5;
"""

pd.read_sql(query8, connection)
# Out:
#     customer_name  total_revenue
# 0  Sharyn Hopkins       34807.94
# 1  Pamelia Newman       33634.26
# 2     Abby Gamble       32803.01
# 3    Lyndsey Bean       32675.07
# 4  Emmitt Sanchez       31925.89

# %% [markdown]
# ### Q9. Show the best-selling product in each category.
#
# Join `products`, `order_items`, and `categories`. For each category, identify the product with the highest total quantity sold.

# %%
# Your query here
query9 = """ 
WITH category_product_sales AS (
    SELECT
        c.category_name,
        p.product_name,
        SUM(oi.quantity) AS total_sold,
        RANK() OVER (
            PARTITION BY c.category_name
            ORDER BY SUM(oi.quantity) DESC
        ) AS rnk
    FROM categories c
    JOIN products p ON c.category_id = p.category_id
    JOIN order_items oi ON p.product_id = oi.product_id
    GROUP BY c.category_name, p.product_name
)
SELECT category_name, product_name, total_sold
FROM category_product_sales
WHERE rnk = 1
ORDER BY category_name;
"""
pd.read_sql(query9, connection)
# Out:
#          category_name                                   product_name  \
# 0    Children Bicycles  Electra Girl's Hawaii 1 (20-inch) - 2015/2016
# 1     Comfort Bicycles         Electra Townie Original 7D - 2015/2016
# 2    Cruisers Bicycles             Electra Cruiser 1 (24-Inch) - 2016
# 3  Cyclocross Bicycles                    Surly Straggler 650b - 2016
# 4       Electric Bikes                           Trek Conduit+ - 2016
# 5       Mountain Bikes          Surly Ice Cream Truck Frameset - 2016
# 6           Road Bikes                  Trek Domane SLR 6 Disc - 2017
#
#    total_sold
# 0         154
# 1         148
# 2         157
# 3         151
# 4         145
# 5         167
# 6          43

# %%
pd.read_sql(""" 
SELECT
        c.category_name,
        p.product_name,
        SUM(oi.quantity) AS total_sold,
        RANK() OVER (
            PARTITION BY c.category_name
            ORDER BY SUM(oi.quantity) DESC
        ) AS rnk
    FROM categories c
    JOIN products p ON c.category_id = p.category_id
    JOIN order_items oi ON p.product_id = oi.product_id
    GROUP BY c.category_name, p.product_name
""", connection)
# Out:
#          category_name                                   product_name  \
# 0    Children Bicycles  Electra Girl's Hawaii 1 (20-inch) - 2015/2016
# 1    Children Bicycles  Electra Girl's Hawaii 1 (16-inch) - 2015/2016
# 2    Children Bicycles             Electra Cruiser 1 (24-Inch) - 2016
# 3    Children Bicycles             Electra Girl's Hawaii 1 16" - 2017
# 4    Children Bicycles     Electra Townie 7D (20-inch) - Boys' - 2017
# ..                 ...                                            ...
# 302         Road Bikes         Trek Domane SL Frameset Women's - 2018
# 303         Road Bikes                Trek Domane SL 5 Women's - 2018
# 304         Road Bikes                       Trek Domane ALR 3 - 2018
# 305         Road Bikes                         Trek CrossRip 2 - 2018
# 306         Road Bikes                      Surly ECR Frameset - 2018
#
#      total_sold  rnk
# 0           154    1
# 1           145    2
# 2           139    3
# 3            47    4
# 4            40    5
# ..          ...  ...
# 302           1   47
# 303           1   47
# 304           1   47
# 305           1   47
# 306           1   47
#
# [307 rows x 4 columns]

# %%
pd.read_sql(""" 
WITH category_product_sales AS (
  SELECT
    c.category_name,
    p.product_name,
    SUM(oi.quantity) AS total_sold
  FROM categories c
  JOIN products p ON c.category_id = p.category_id
  JOIN order_items oi ON p.product_id = oi.product_id
  GROUP BY c.category_name, p.product_name
)

SELECT
  category_name,
  product_name,
  MAX(total_sold)
FROM category_product_sales
GROUP BY category_name;        
""", connection)
# Out:
#          category_name                                   product_name  \
# 0    Children Bicycles  Electra Girl's Hawaii 1 (20-inch) - 2015/2016
# 1     Comfort Bicycles         Electra Townie Original 7D - 2015/2016
# 2    Cruisers Bicycles             Electra Cruiser 1 (24-Inch) - 2016
# 3  Cyclocross Bicycles                    Surly Straggler 650b - 2016
# 4       Electric Bikes                           Trek Conduit+ - 2016
# 5       Mountain Bikes          Surly Ice Cream Truck Frameset - 2016
# 6           Road Bikes                  Trek Domane SLR 6 Disc - 2017
#
#    MAX(total_sold)
# 0              154
# 1              148
# 2              157
# 3              151
# 4              145
# 5              167
# 6               43

# %% [markdown]
# ### Q10. Identify the employees (staff) who processed the most orders.
#
# Join `staffs` and `orders`. Count the number of orders handled by each staff member and return the results sorted by highest total.

# %%
query10 = """
SELECT
  CONCAT(staffs.first_name, ' ', staffs.last_name) AS staff_name,
  COUNT(order_id) AS order_count
FROM orders
JOIN staffs ON orders.staff_id = staffs.staff_id
GROUP BY CONCAT( staffs.first_name, ' ', staffs.last_name)
ORDER BY order_count DESC;
"""

pd.read_sql(query10, connection)
# Out:
#         staff_name  order_count
# 0  Marcelene Boyer          553
# 1    Venita Daniel          540
# 2    Genna Serrano          184
# 3  Mireya Copeland          164
# 4      Kali Vargas           88
# 5    Layla Terrell           86
